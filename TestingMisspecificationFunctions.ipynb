# %%
import matplotlib.pyplot as plt
import numpy as np
from diffusionProcess import DiffusionProcess, drift, sigma, generate_linear_drift, generate_non_linear_drift

# %% [markdown]
# # Testing the effect of breaking the linear drift

# %%
def b1(power: float):
    return lambda x: -x**power

powers = [3, 5, 7, 29]


drifts = [b1(p) for p in powers]
diffProsses = [DiffusionProcess(d, sigma) for d in drifts]

x_range_invariant = np.linspace(-5, 5, 100)
x_range_xi = np.linspace(0, 1, 100)
invariant_densities = [pros.invariant_density(x_range_invariant) for pros in diffProsses]
expected_hitting_times = [pros.xi(x_range_xi) for pros in diffProsses]

fig, ax = plt.subplots(1,2,figsize=(16,5))

for i, invariant_density in enumerate(invariant_densities):
    ax[0].plot(x_range_invariant, invariant_density, label=f"power1 = {powers[i]}" )
ax[0].legend(loc="upper left")
ax[0].set_title("Invariant density")
for i, expected_hitting_time in enumerate(expected_hitting_times):
    ax[1].plot(x_range_xi, expected_hitting_time, label=f"power1 = {powers[i]}")
ax[1].legend(loc="upper left")
ax[1].set_title("Expected hitting times")
ax[1].ticklabel_format(style="plain")
#ax[1].set_ylim([0, 100])
plt.show()

# %%
def b2(C: float, power1: float, power2: float):
    return lambda x: -C*x**power1 + x**power2

powers1 = [3, 5, 7, 29]
powers2 = [1,3,5, 1]

drifts = [b2(1, p1, p2) for p1, p2 in zip(powers1, powers2)]
diffProsses = [DiffusionProcess(d, sigma) for d in drifts]

x_range_invariant = np.linspace(-5, 5, 100)
x_range_xi = np.linspace(0, 1, 100)
invariant_densities = [pros.invariant_density(x_range_invariant) for pros in diffProsses]
expected_hitting_times = [pros.xi(x_range_xi) for pros in diffProsses]

fig, ax = plt.subplots(1,2,figsize=(16,5))

for i, invariant_density in enumerate(invariant_densities):
    ax[0].plot(x_range_invariant, invariant_density, label=f"power1 = {powers1[i]}, power2 = {powers2[i]}" )
ax[0].legend(loc="upper left")
ax[0].set_title("Invariant density")
for i, expected_hitting_time in enumerate(expected_hitting_times):
    ax[1].plot(x_range_xi, expected_hitting_time, label=f"power1 = {powers1[i]}, power2 = {powers2[i]}")
ax[1].legend(loc="upper left")
ax[1].set_title("Expected hitting times")
ax[1].ticklabel_format(style="plain")
#ax[1].set_ylim([0, 100])
plt.show()

# %%
def b3(power: float):
    return lambda x: -x**power + x**2+x

powers = [3, 5, 7, 29]


drifts = [b3(p1) for p1 in powers]
diffProsses = [DiffusionProcess(d, sigma) for d in drifts]

x_range_invariant = np.linspace(-5, 5, 100)
x_range_xi = np.linspace(0, 1, 100)
invariant_densities = [pros.invariant_density(x_range_invariant) for pros in diffProsses]
expected_hitting_times = [pros.xi(x_range_xi) for pros in diffProsses]

fig, ax = plt.subplots(1,2,figsize=(16,5))

for i, invariant_density in enumerate(invariant_densities):
    ax[0].plot(x_range_invariant, invariant_density, label=f"power = {powers[i]}" )
ax[0].legend(loc="upper left")
ax[0].set_title("Invariant density")
for i, expected_hitting_time in enumerate(expected_hitting_times):
    ax[1].plot(x_range_xi, expected_hitting_time, label=f"power = {powers[i]}")
ax[1].legend(loc="upper left")
ax[1].set_title("Expected hitting times")
ax[1].ticklabel_format(style="plain")
#ax[1].set_ylim([0, 100])
plt.show()

# %% [markdown]
# # Testing the effect of breaking the ergodic assumptions

# %%
def b4(C: float):
    return lambda x: C*x

Cs = [0.001, 0.005, 0.01, 0.02]

drifts = [b4(c) for c in Cs]
diffProsses = [DiffusionProcess(d, sigma) for d in drifts]

x_range_invariant = np.linspace(-5, 5, 100)
x_range_xi = np.linspace(0, 1, 100)
invariant_densities = [pros.invariant_density(x_range_invariant) for pros in diffProsses]
expected_hitting_times = [pros.xi(x_range_xi) for pros in diffProsses]

fig, ax = plt.subplots(1,2,figsize=(16,5))

for i, invariant_density in enumerate(invariant_densities):
    ax[0].plot(x_range_invariant, invariant_density, label=f"C = {Cs[i]}" )
ax[0].legend(loc="upper left")
ax[0].set_title("Invariant density")
for i, expected_hitting_time in enumerate(expected_hitting_times):
    ax[1].plot(x_range_xi, expected_hitting_time, label=f"C = {Cs[i]}")
ax[1].legend(loc="upper left")
ax[1].set_title("Expected hitting times")
ax[1].ticklabel_format(style="plain")
#ax[1].set_ylim([0, 100])
plt.show()
# Out:
# c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:78: RuntimeWarning: overflow encountered in exp
#   f = lambda u: 1/self.sigma(u)**2 * np.exp(inner_integral(u))
# c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:79: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return quad(f, -np.inf, np.inf, epsabs=1e-3, limit=250)[0]
# c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:96: RuntimeWarning: divide by zero encountered in double_scalars
#   f = lambda y: 1/(self.sigma(y)**2 * self.invariant_density(y)) * inner_integral(y)
# c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   f = lambda y: 1/(self.sigma(y)**2 * self.invariant_density(y)) * inner_integral(y)
# c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:98: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   return 2*np.array(list(map(partial(quad, f, 0, epsabs=1e-3, limit=100), x)))[:, 0]
# c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:98: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2*np.array(list(map(partial(quad, f, 0, epsabs=1e-3, limit=100), x)))[:, 0]
# c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:88: RuntimeWarning: overflow encountered in exp
#   return 1/self.C_b_sigma_val * np.exp(integral(x))
# c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:94: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return quad(self.invariant_density, -np.inf, y, epsabs=1e-3, limit=100)[0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 13
#      11 x_range_xi = np.linspace(0, 1, 100)
#      12 invariant_densities = [pros.invariant_density(x_range_invariant) for pros in diffProsses]
# ---> 13 expected_hitting_times = [pros.xi(x_range_xi) for pros in diffProsses]
#      15 fig, ax = plt.subplots(1,2,figsize=(16,5))
#      17 for i, invariant_density in enumerate(invariant_densities):
#
# Cell In[34], line 13, in <listcomp>(.0)
#      11 x_range_xi = np.linspace(0, 1, 100)
#      12 invariant_densities = [pros.invariant_density(x_range_invariant) for pros in diffProsses]
# ---> 13 expected_hitting_times = [pros.xi(x_range_xi) for pros in diffProsses]
#      15 fig, ax = plt.subplots(1,2,figsize=(16,5))
#      17 for i, invariant_density in enumerate(invariant_densities):
#
# File c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:98, in DiffusionProcess.xi(self, x)
#      96 f = lambda y: 1/(self.sigma(y)**2 * self.invariant_density(y)) * inner_integral(y)
#      97 if isinstance(x, Iterable):
# ---> 98     return 2*np.array(list(map(partial(quad, f, 0, epsabs=1e-3, limit=100), x)))[:, 0]
#      99 return 2*quad(f, 0, x, epsabs=1e-3, limit=100)[0]
#
# File c:\Users\razz_\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_quadpack_py.py:464, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     461     return retval
#     463 if weight is None:
# --> 464     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     465                    points)
#     466 else:
#     467     if points is not None:
#
# File c:\Users\razz_\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_quadpack_py.py:611, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     609 if points is None:
#     610     if infbounds == 0:
# --> 611         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     612     else:
#     613         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     614                                 epsabs, epsrel, limit)
#
# File c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:96, in DiffusionProcess.xi.<locals>.<lambda>(y)
#      93         return np.array(list(map(partial(quad, self.invariant_density, -np.inf, epsabs=1e-3, limit=100), y)))[:, 0]
#      94     return quad(self.invariant_density, -np.inf, y, epsabs=1e-3, limit=100)[0]
# ---> 96 f = lambda y: 1/(self.sigma(y)**2 * self.invariant_density(y)) * inner_integral(y)
#      97 if isinstance(x, Iterable):
#      98     return 2*np.array(list(map(partial(quad, f, 0, epsabs=1e-3, limit=100), x)))[:, 0]
#
# File c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:94, in DiffusionProcess.xi.<locals>.inner_integral(y)
#      92 if isinstance(y, Iterable):
#      93     return np.array(list(map(partial(quad, self.invariant_density, -np.inf, epsabs=1e-3, limit=100), y)))[:, 0]
# ---> 94 return quad(self.invariant_density, -np.inf, y, epsabs=1e-3, limit=100)[0]
#
# File c:\Users\razz_\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_quadpack_py.py:464, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     461     return retval
#     463 if weight is None:
# --> 464     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     465                    points)
#     466 else:
#     467     if points is not None:
#
# File c:\Users\razz_\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_quadpack_py.py:613, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     611         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     612     else:
# --> 613         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     614                                 epsabs, epsrel, limit)
#     615 else:
#     616     if infbounds != 0:
#
# File c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:88, in DiffusionProcess.invariant_density(self, x)
#      85         return np.array(list(map(partial(quad, f, 0, limit=100, epsabs = 1e-3), x)))[:, 0]
#      86     return quad(f, 0, x, epsabs=1e-3, limit=100)[0]
# ---> 88 return 1/self.C_b_sigma_val * np.exp(integral(x))
#
# File c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:86, in DiffusionProcess.invariant_density.<locals>.integral(x)
#      84 if isinstance(x, Iterable):
#      85     return np.array(list(map(partial(quad, f, 0, limit=100, epsabs = 1e-3), x)))[:, 0]
# ---> 86 return quad(f, 0, x, epsabs=1e-3, limit=100)[0]
#
# File c:\Users\razz_\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_quadpack_py.py:464, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     461     return retval
#     463 if weight is None:
# --> 464     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     465                    points)
#     466 else:
#     467     if points is not None:
#
# File c:\Users\razz_\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_quadpack_py.py:611, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     609 if points is None:
#     610     if infbounds == 0:
# --> 611         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     612     else:
#     613         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     614                                 epsabs, epsrel, limit)
#
# File c:\Projects\Data-driven-algorithms-for-Impulse-control-problem-Thesis\diffusionProcess.py:83, in DiffusionProcess.invariant_density.<locals>.integral.<locals>.<lambda>(y)
#      82 def integral(x):
# ---> 83     f = lambda y: 2*self.b(y)/self.sigma(y)**2
#      84     if isinstance(x, Iterable):
#      85         return np.array(list(map(partial(quad, f, 0, limit=100, epsabs = 1e-3), x)))[:, 0]
#
# Cell In[34], line 2, in b4.<locals>.<lambda>(x)
#       1 def b4(C: float):
# ----> 2     return lambda x: C*x
#
# KeyboardInterrupt:
